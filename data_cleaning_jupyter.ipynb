# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataSciece.changeDirOnImportExport setting
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %%
# ## Importing Survey Data

import pandas as pd
houses = pd.read_csv('~/pytong/data-cleaning/thads2013n.txt')

# %%
# looking at database shape
house_shape = houses.shape
print(house_shape)
# Out:
# (64535, 99)

# %%
# looking at first 10 rows
print(houses.head(10))
# Out:
#           CONTROL  AGE1 METRO3 REGION   LMED   FMR    L30    L50    L80  \
# 0  '100003130103'    82    '3'    '1'  73738   956  15738  26213  40322
# 1  '100006110249'    50    '5'    '3'  55846  1100  17165  28604  45744
# 2  '100006370140'    53    '5'    '3'  55846  1100  13750  22897  36614
# 3  '100006520140'    67    '5'    '3'  55846   949  13750  22897  36614
# 4  '100007130148'    26    '1'    '3'  60991   737  14801  24628  39421
# 5  '100007390148'    56    '2'    '3'  62066   657  13170  21924  35073
# 6  '100007540148'    50    '1'    '3'  60991   988  16646  27713  44340
# 7  '100008700141'    26    '4'    '4'  52322   773  13489  22471  35929
# 8  '100008960141'    60    '5'    '4'  50296  1125  13115  21859  34939
# 9  '100009170148'    26    '4'    '2'  63221   552  13338  22199  35501
#
#     IPOV    ...          FMTINCRELFMRCAT  FMTCOST06RELAMICAT  \
# 0  11067    ...          '1 LTE 50% FMR'    '2 30 - 50% AMI'
# ...

# %%
# looking at columns names
print(houses.columns)
# Out:
# Index([u'CONTROL', u'AGE1', u'METRO3', u'REGION', u'LMED', u'FMR', u'L30',
#        u'L50', u'L80', u'IPOV', u'BEDRMS', u'BUILT', u'STATUS', u'TYPE',
#        u'VALUE', u'VACANCY', u'TENURE', u'NUNITS', u'ROOMS', u'WEIGHT', u'PER',
#        u'ZINC2', u'ZADEQ', u'ZSMHC', u'STRUCTURETYPE', u'OWNRENT', u'UTILITY',
#        u'OTHERCOST', u'COST06', u'COST12', u'COST08', u'COSTMED', u'TOTSAL',
#        u'ASSISTED', u'GLMED', u'GL30', u'GL50', u'GL80', u'APLMED', u'ABL30',
#        u'ABL50', u'ABL80', u'ABLMED', u'BURDEN', u'INCRELAMIPCT',
#        u'INCRELAMICAT', u'INCRELPOVPCT', u'INCRELPOVCAT', u'INCRELFMRPCT',
#        u'INCRELFMRCAT', u'COST06RELAMIPCT', u'COST06RELAMICAT',
#        u'COST06RELPOVPCT', u'COST06RELPOVCAT', u'COST06RELFMRPCT',
#        u'COST06RELFMRCAT', u'COST08RELAMIPCT', u'COST08RELAMICAT',
#        u'COST08RELPOVPCT', u'COST08RELPOVCAT', u'COST08RELFMRPCT',
#        u'COST08RELFMRCAT', u'COST12RELAMIPCT', u'COST12RELAMICAT',
# ...
